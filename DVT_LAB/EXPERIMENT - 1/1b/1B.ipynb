# %%
#SAMPLE
import pandas as pd
df = pd.read_csv("Instagram_Analytics.csv")

# %%
df.head()
# Out:
#      post_id  account_id account_type  follower_count media_type  \
# 0  IG0000001           7        brand            3551       reel
# 1  IG0000002          20      creator           31095      image
# 2  IG0000003          15        brand            8167       reel
# 3  IG0000004          11      creator            9044   carousel
# 4  IG0000005           8      creator           15986       reel
#
#   content_category traffic_source  has_call_to_action        post_datetime  \
# 0       Technology      Home Feed                   1  2024-11-30 06:00:00
# 1          Fitness       Hashtags                   1  2025-08-15 15:00:00
# 2           Beauty     Reels Feed                   0  2025-09-11 16:00:00
# 3            Music       External                   0  2025-09-18 03:00:00
# 4       Technology        Profile                   0  2025-03-21 09:00:00
#
#     post_date  ...  comments shares  saves  reach  impressions  \
# ...

# %%
df.tail()
# Out:
#          post_id  account_id account_type  follower_count media_type  \
# 29994  IG0029995           5        brand           10739   carousel
# 29995  IG0029996           3        brand           10018      image
# 29996  IG0029997          18      creator            7486      image
# 29997  IG0029998           6      creator           10034   carousel
# 29998  IG0029999           9      creator            6916      image
#
#       content_category traffic_source  has_call_to_action  \
# 29994           Travel     Reels Feed                   0
# 29995           Beauty       Hashtags                   0
# 29996      Photography        Explore                   1
# 29997       Technology        Explore                   1
# 29998       Technology        Explore                   1
#
#              post_datetime   post_date  ...  comments shares  saves  reach  \
# 29994  2024-12-18 10:00:00  2024-12-18  ...         1      2      5   1564
# ...

# %%
print("Shape:", df.shape)
# Out:
# Shape: (29999, 23)

# %%
sample_df = df.sample(frac=0.7, random_state=42)

# %%
print("Sample Shape:", sample_df.shape)
# Out:
# Sample Shape: (20999, 23)

# %%
#EXPLORE
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20999 entries, 2308 to 5419
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   post_id                   20999 non-null  object
#  1   account_id                20999 non-null  int64
#  2   account_type              20999 non-null  object
#  3   follower_count            20999 non-null  int64
#  4   media_type                20999 non-null  object
#  5   content_category          20999 non-null  object
#  6   traffic_source            20999 non-null  object
#  7   has_call_to_action        20999 non-null  int64
#  8   post_datetime             20999 non-null  object
#  9   post_date                 20999 non-null  object
#  10  post_hour                 20999 non-null  int64
#  11  day_of_week               20999 non-null  object
#  12  likes                     20999 non-null  int64
# ...

# %%
sample_df.describe().T
# Out:
#                       count          mean          std     min       25%  \
# account_id          20999.0     10.564074     5.752373     1.0     6.000
# follower_count      20999.0  10272.369637  6685.471610  3083.0  5824.000
# has_call_to_action  20999.0      0.348636     0.476550     0.0     0.000
# post_hour           20999.0     11.492357     6.897107     0.0     6.000
# likes               20999.0    291.554455   333.088779     0.0   104.000
# comments            20999.0      8.628887    10.619238     0.0     3.000
# shares              20999.0     14.636507    17.225875     0.0     5.000
# saves               20999.0     43.015763    49.918302     0.0    15.000
# reach               20999.0   6264.382256  4988.506551   349.0  3048.500
# impressions         20999.0   8454.334635  6825.899216   400.0  4085.000
# engagement_rate     20999.0      0.042692     0.025745     0.0     0.024
# followers_gained    20999.0    502.717558   290.300097     0.0   251.000
# ...

# %%
sample_df.describe().T
# Out:
#                       count          mean          std     min       25%  \
# account_id          20999.0     10.564074     5.752373     1.0     6.000
# follower_count      20999.0  10272.369637  6685.471610  3083.0  5824.000
# has_call_to_action  20999.0      0.348636     0.476550     0.0     0.000
# post_hour           20999.0     11.492357     6.897107     0.0     6.000
# likes               20999.0    291.554455   333.088779     0.0   104.000
# comments            20999.0      8.628887    10.619238     0.0     3.000
# shares              20999.0     14.636507    17.225875     0.0     5.000
# saves               20999.0     43.015763    49.918302     0.0    15.000
# reach               20999.0   6264.382256  4988.506551   349.0  3048.500
# impressions         20999.0   8454.334635  6825.899216   400.0  4085.000
# engagement_rate     20999.0      0.042692     0.025745     0.0     0.024
# followers_gained    20999.0    502.717558   290.300097     0.0   251.000
# ...

# %%
sample_df.describe(include='object').T
# Out:
#                           count unique                  top   freq
# post_id                   20999  20999            IG0002309      1
# account_type              20999      2              creator  14692
# media_type                20999      3                image   8312
# content_category          20999     10           Technology   2144
# traffic_source            20999      6            Home Feed   3564
# post_datetime             20999   7938  2025-02-27 06:00:00     10
# post_date                 20999    366           2025-02-26     80
# day_of_week               20999      7            Wednesday   3057
# performance_bucket_label  20999      4                  low   5295

# %%
print(sample_df.isnull().sum())
# Out:
# post_id                     0
# account_id                  0
# account_type                0
# follower_count              0
# media_type                  0
# content_category            0
# traffic_source              0
# has_call_to_action          0
# post_datetime               0
# post_date                   0
# post_hour                   0
# day_of_week                 0
# likes                       0
# comments                    0
# shares                      0
# saves                       0
# reach                       0
# impressions                 0
# engagement_rate             0
# followers_gained            0
# caption_length              0
# hashtags_count              0
# performance_bucket_label    0
# dtype: int64

# %%
print("Duplicate Rows:", sample_df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numeric_df = sample_df.select_dtypes(include=['number'])

plt.figure(figsize=(12,8))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
plt.figure(figsize=(6,4))

sns.countplot(
    data=sample_df,
    x="performance_bucket_label"
)

plt.title("Performance Bucket Distribution")
plt.show()

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    data=sample_df,
    x='reach',
    y='impressions',
    hue='performance_bucket_label'
)

plt.show()

# %%
plt.figure(figsize=(7,5))

sns.histplot(
    sample_df["likes"],
    bins=30,
    kde=True
)

plt.show()

# %%
#MODIFY
df_clean = sample_df.copy()

num_cols = df_clean.select_dtypes(include=['number']).columns

df_clean[num_cols] = df_clean[num_cols].fillna(
    df_clean[num_cols].median()
)

cat_cols = df_clean.select_dtypes(include=['object']).columns

df_clean[cat_cols] = df_clean[cat_cols].fillna(
    df_clean[cat_cols].mode().iloc[0]
)

# %%
df_clean.drop_duplicates(inplace=True)

# %%
df_clean['post_datetime'] = pd.to_datetime(df_clean['post_datetime'])
df_clean['post_date'] = pd.to_datetime(df_clean['post_date'])

# %%
df_clean["Year"] = df_clean["post_datetime"].dt.year
df_clean["Month"] = df_clean["post_datetime"].dt.month
df_clean["Day"] = df_clean["post_datetime"].dt.day
df_clean["Hour"] = df_clean["post_datetime"].dt.hour
df_clean["Weekday"] = df_clean["post_datetime"].dt.day_name()

# %%
df_clean.drop(
    columns=["post_id"],
    inplace=True
)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

categorical_columns = df_clean.select_dtypes(include='object').columns

for col in categorical_columns:
    df_clean[col] = le.fit_transform(df_clean[col])

# %%
X = df_clean.drop("performance_bucket_label", axis=1)
y = df_clean["performance_bucket_label"]

X = X.drop(
    columns=["post_datetime","post_date"],
    errors="ignore"
)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
#MODEL
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf.fit(X_train,y_train)

print("Model Trained Successfully")
# Out:
# Model Trained Successfully

# %%
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(
    y_test,
    y_pred
)

print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.9002380952380953

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test,y_pred)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

plt.show()
